# %% [markdown]
# <a href="https://colab.research.google.com/github/srathina/Python/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x  = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y1 = [1, 3, 5, 3, 1, 3, 5, 3, 1]
y2 = [2, 4, 6, 4, 2, 4, 6, 4, 2]
plt.plot(x, y1, label="line L")
plt.plot(x, y2, label="line H")

plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line Graph Example")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-adb3e12e7a13> in <module>()
#       7 plt.plot(x, y2, label="line H")
#       8
# ----> 9 plt.xlabel("x axis",1)
#      10 plt.ylabel("y axis",1)
#      11 plt.title("Line Graph Example")
#
# TypeError: 'str' object is not callable
